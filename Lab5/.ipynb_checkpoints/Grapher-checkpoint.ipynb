# %%
# %pylab inline
data = np.loadtxt("coordinates.csv", dtype=int, delimiter=',');
x = data[:,0]
y = data[:,1]
plt.plot(x, y, "*")
plt.xlim(-20, 140)
plt.ylim(-20, 120)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (-20, 120)
